# %%
cd D:/shen
# Out:
# D:\shen

# %%
import os
import numpy as np
import nibabel as nib
from nilearn.maskers import NiftiMasker
from scipy.io import loadmat
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import numpy as np


file_path1 = 'speak_va_268.h5'
file_path2 = 'speak_vb_268.h5'
file_path3 = 'listen_va_268.h5'
file_path4 = 'listen_vb_268.h5'

def load_data1(file_path):
    """
    Function to load data from datasets with names p_values1_i and corrected_p_values1_i 
    (where i ranges from 0 to 399) from a given file path, and store them in separate lists.
    """
    data1_list = []  # List to store data from p_values1_ datasets
    with h5py.File(file_path, 'r') as file:
        for i in range(269):  # Iterate over indices from 0 to 399
            pname = f'subarray_{i}'
            # Check and read p_values1_ dataset
            if pname in file:
                if file[pname].shape:  # Check if dataset is not a scalar
                    data1 = file[pname][:]
                else:
                    data1 = file[pname][()]  # Handle scalar dataset
                data1_list.append(data1)
            else:
                print(f"Dataset '{pname}' not found in the file.")

        return data1_list


# Load data for each file
all_vas_list = load_data1(file_path1)
all_vbs_list = load_data1(file_path2)
all_var_list = load_data1(file_path3)
all_vbr_list = load_data1(file_path4)

# %%
def process_and_stack(arr):
    f2, f5 = arr[:, :12, :10], arr[:, 12:24, :15]
    return np.concatenate([f2.mean(2),f5.mean(2)], axis=1)


# Initialize the final results list
stacked_vas_list = []
stacked_var_list = []
stacked_vbs_list = []
stacked_vbr_list = []


for brain_area in range(268):
    new_vas=all_vas_list[brain_area] 
    new_vbs=all_vbs_list[brain_area] 
    new_var=all_var_list[brain_area] 
    new_vbr=all_vbr_list[brain_area] 
    
    print("Rearranging and stacking data...")
    stacked_vas, stacked_var, stacked_vbs, stacked_vbr = [process_and_stack(data) for data in [new_vas, new_var, new_vbs, new_vbr]]
    print("Data rearranged and stacked.")
    stacked_vas_list.append(stacked_vas)
    stacked_var_list.append(stacked_var)
    stacked_vbs_list.append(stacked_vbs)
    stacked_vbr_list.append(stacked_vbr)


# In[1]:


import h5py
import numpy as np


# Create an HDF5 file
with h5py.File('face268_speak_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vas_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('face268_speak_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbs_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

with h5py.File('face268_listen_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_var_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('face268_listen_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbr_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

# %%
import os
import numpy as np
import nibabel as nib
from nilearn.maskers import NiftiMasker
from scipy.io import loadmat
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import numpy as np


file_path1 = 'view_va_268.h5'
file_path2 = 'view_vb_268.h5'
file_path3 = 'imagery_va_268.h5'
file_path4 = 'imagery_vb_268.h5'

def load_data1(file_path):
    """
    Function to load data from datasets with names p_values1_i and corrected_p_values1_i 
    (where i ranges from 0 to 399) from a given file path, and store them in separate lists.
    """
    data1_list = []  # List to store data from p_values1_ datasets
    with h5py.File(file_path, 'r') as file:
        for i in range(268):  # Iterate over indices from 0 to 399
            pname = f'subarray_{i}'
            # Check and read p_values1_ dataset
            if pname in file:
                if file[pname].shape:  # Check if dataset is not a scalar
                    data1 = file[pname][:]
                else:
                    data1 = file[pname][()]  # Handle scalar dataset
                data1_list.append(data1)
            else:
                print(f"Dataset '{pname}' not found in the file.")

        return data1_list


# Load data for each file
all_vas_list = load_data1(file_path1)
all_vbs_list = load_data1(file_path2)
all_var_list = load_data1(file_path3)
all_vbr_list = load_data1(file_path4)

# %%
def process_and_stack(arr):
    f2, f5 = arr[:, :12, :6], arr[:, 12:24, :6]
    return np.concatenate([f2.mean(2),f5.mean(2)], axis=1)


# Initialize the final results list
stacked_vas_list = []
stacked_var_list = []
stacked_vbs_list = []
stacked_vbr_list = []


for brain_area in range(268):
    new_vas=all_vas_list[brain_area] 
    new_vbs=all_vbs_list[brain_area] 
    new_var=all_var_list[brain_area] 
    new_vbr=all_vbr_list[brain_area] 
    
    print("Rearranging and stacking data...")
    stacked_vas, stacked_var, stacked_vbs, stacked_vbr = [process_and_stack(data) for data in [new_vas, new_var, new_vbs, new_vbr]]
    print("Data rearranged and stacked.")
    stacked_vas_list.append(stacked_vas)
    stacked_var_list.append(stacked_var)
    stacked_vbs_list.append(stacked_vbs)
    stacked_vbr_list.append(stacked_vbr)


# In[1]:


import h5py
import numpy as np


# Create an HDF5 file
with h5py.File('face268_view_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vas_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('face268_view_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbs_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

with h5py.File('face268_imagery_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_var_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('face268_imagery_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbr_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

# %%
import os
import numpy as np
import nibabel as nib
import seaborn as sns
import matplotlib.pyplot as plt

####-------------------------------------
    
import numpy as np

def process_data_and_get_corr_matrix(num_pairs, v1, v2):
    """
    Process data and return the correlation matrices without leave-one-out iteration.
    """
    corr_matrices = []

    for pair_num in range(num_pairs):
        send_stack = v1[pair_num]
        rece_stack = v2[pair_num]

        # Concatenate the two conditions
        pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

        # Calculate the correlation matrix
        corr_matrix = np.corrcoef(pair_matrix)

        # Fisher's Z Transformation
        fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

        # Extract the part of the matrix that correlates the two conditions
        corr_matrix_half = fisher_z_matrix[:send_stack.shape[0], send_stack.shape[0]:]  
        corr_matrices.append(corr_matrix_half)

    corr_matrices = np.array(corr_matrices)

    return corr_matrices


def calculate_z_corr_matrix2(corr_matrices_12, corr_matrices_34):
    corr_matrices_34 = np.array(corr_matrices_34)
    corr_matrices_12 = np.array(corr_matrices_12)
    corr_matrix_all = np.vstack((corr_matrices_12, corr_matrices_34))
    return corr_matrix_all
###---------------------------------------------------------------
import h5py
# Define the file paths
file_path1 = 'face268_imagery_va.h5'
file_path2 = 'face268_imagery_vb.h5'
file_path3 = 'face268_speak_va.h5'
file_path4 = 'face268_speak_vb.h5'

def load_data(file_path):
    """Function to load data from subarray_0 to subarray_199 from a given file path."""
    with h5py.File(file_path, 'r') as file:
        data_list = []
        for i in range(268):  # Load from subarray_0 to subarray_399
            dataset_name = f'subarray_{i}'
            if dataset_name in file:
                data = file[dataset_name][:]
                data_list.append(data)
            else:
                print(f"Dataset '{dataset_name}' not found in the file.")
        return data_list

# Load data for each file
stacked_var_list = load_data(file_path1)
stacked_vbr_list = load_data(file_path2)
stacked_vas_list = load_data(file_path3)
stacked_vbs_list = load_data(file_path4)

import numpy as np

def check_for_nans(data_list, list_name):
    """Function to check for NaN values in a list of datasets."""
    for i, dataset in enumerate(data_list):
        if np.isnan(dataset).any():
            print(f"NaN found in dataset {i} of {list_name}")

# Check each list for NaN values
check_for_nans(stacked_var_list, 'stacked_var_list')
check_for_nans(stacked_vbr_list, 'stacked_vbr_list')
check_for_nans(stacked_vas_list, 'stacked_vas_list')
check_for_nans(stacked_vbs_list, 'stacked_vbs_list')

all_correlations_real1 = []
all_z_correlations_real = []
all_correlations_real2 = []
all_correlations_real3 = []
all_correlations_real4 = []
all_z_correlations_real_sr = []

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    real_corr_sarb = process_data_and_get_corr_matrix(num_pairsa,vas_data, vbr_data)
    all_correlations_real1.append(real_corr_sarb)

    # Calculate average_cross_pair_correlation
    real_corr_rbsa = process_data_and_get_corr_matrix(num_pairsa,vbr_data, vas_data)
    all_correlations_real3.append(real_corr_rbsa)

    real_corr_sbra = process_data_and_get_corr_matrix(num_pairsa,vbs_data, var_data)
    all_correlations_real2.append(real_corr_sbra)

    # Calculate average_cross_pair_correlation
    real_corr_rasb  = process_data_and_get_corr_matrix(num_pairsa,var_data,vbs_data)
    all_correlations_real4.append(real_corr_rasb)
    
    z_corr_matrix_real = calculate_z_corr_matrix2(real_corr_sarb, real_corr_sbra)
    all_z_correlations_real.append(z_corr_matrix_real)
    
    # print("finish real")

import h5py

# Define file paths for saving
file_path5 = 'face268_z_correlations_real_si.h5'
# Save all_z_correlations_real
with h5py.File(file_path5, 'w') as h5f:
    # Assuming all_z_correlations_real is a list of NumPy arrays
    for i, matrix in enumerate(all_z_correlations_real):
        h5f.create_dataset(f'z_corr_matrix_{i}', data=matrix)
        
print("finish output real")

#-------------------------------
import numpy as np

def calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize):
    all_correlations = []

    for send_pair_num in range(num_pairs):
        send_stack = v1[send_pair_num]
        pair_correlations = []

        for rece_pair_num in range(num_pairs):
            if send_pair_num == rece_pair_num:
                continue  # Skip the same pair

            rece_stack = v2[rece_pair_num]

            # Concatenate the two conditions for this pair
            pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

            # Compute the correlation matrix
            corr_matrix = np.corrcoef(pair_matrix)

            # Fisher's Z Transformation
            fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

            # Extract the part of the matrix that correlates the two conditions
            corr_matrix_half = fisher_z_matrix[:cdsize, cdsize:]
            pair_correlations.append(corr_matrix_half)

        all_correlations.append(pair_correlations)

    return all_correlations

def average_cross_pair_correlation(num_pairs, v1, v2,cdsize):
    all_correlations = calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize)
    average_correlations = []
    for send_pair_num in range(num_pairs):
        avg_corr = np.mean(all_correlations[send_pair_num], axis=0)
        average_correlations.append(avg_corr)
    return average_correlations

def grandavg_norealpair_correlation(v1_list, v2_list):
    grandavg_correlations = []
    for send_pair_num in range(len(v1_list)):
        avg_corr = (v1_list[send_pair_num] + v2_list[send_pair_num]) / 2
        grandavg_correlations.append(avg_corr)
    return grandavg_correlations



all_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_correlations_rasb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rasb = []  # Store cross_pair_correlation for each brain region

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sarb = calculate_cross_pair_correlation(num_pairsa,vas_data, vbr_data, cdsize=24)
    all_correlations_sarb.append(cross_corr_sarb)

    cross_corr_rbsa = calculate_cross_pair_correlation(num_pairsa,vbr_data, vas_data, cdsize=24)
    all_correlations_rbsa.append(cross_corr_rbsa)


for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sbra = calculate_cross_pair_correlation(num_pairsa,vbs_data, var_data, cdsize=24)
    all_correlations_sbra.append(cross_corr_sbra)


    cross_corr_rasb = calculate_cross_pair_correlation(num_pairsa,var_data, vbs_data, cdsize=24)
    all_correlations_rasb.append(cross_corr_rasb)

# # Define file paths for saving
file_path6 = 'face268_cross_correlations_si.h5'

# Save the data
with h5py.File(file_path6, 'w') as h5f:
    # Assuming all lists are lists of NumPy arrays
    for i, matrix in enumerate(all_correlations_sarb):
        h5f.create_dataset(f'all_correlations_sarb_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rbsa):
        h5f.create_dataset(f'all_correlations_rbsa_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_sbra):
        h5f.create_dataset(f'all_correlations_sbra_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rasb):
        h5f.create_dataset(f'all_correlations_rasb_{i}', data=matrix)
        
print("finish output cross")

# %%
import os
import numpy as np
import nibabel as nib
import seaborn as sns
import matplotlib.pyplot as plt

####-------------------------------------
    
import numpy as np

def process_data_and_get_corr_matrix(num_pairs, v1, v2):
    """
    Process data and return the correlation matrices without leave-one-out iteration.
    """
    corr_matrices = []

    for pair_num in range(num_pairs):
        send_stack = v1[pair_num]
        rece_stack = v2[pair_num]

        # Concatenate the two conditions
        pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

        # Calculate the correlation matrix
        corr_matrix = np.corrcoef(pair_matrix)

        # Fisher's Z Transformation
        fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

        # Extract the part of the matrix that correlates the two conditions
        corr_matrix_half = fisher_z_matrix[:send_stack.shape[0], send_stack.shape[0]:]  
        corr_matrices.append(corr_matrix_half)

    corr_matrices = np.array(corr_matrices)

    return corr_matrices


def calculate_z_corr_matrix2(corr_matrices_12, corr_matrices_34):
    corr_matrices_34 = np.array(corr_matrices_34)
    corr_matrices_12 = np.array(corr_matrices_12)
    corr_matrix_all = np.vstack((corr_matrices_12, corr_matrices_34))
    return corr_matrix_all
###---------------------------------------------------------------
import h5py
# Define the file paths
file_path1 = 'face268_imagery_va.h5'
file_path2 = 'face268_imagery_vb.h5'
file_path3 = 'face268_view_va.h5'
file_path4 = 'face268_view_vb.h5'

def load_data(file_path):
    """Function to load data from subarray_0 to subarray_199 from a given file path."""
    with h5py.File(file_path, 'r') as file:
        data_list = []
        for i in range(268):  # Load from subarray_0 to subarray_399
            dataset_name = f'subarray_{i}'
            if dataset_name in file:
                data = file[dataset_name][:]
                data_list.append(data)
            else:
                print(f"Dataset '{dataset_name}' not found in the file.")
        return data_list

# Load data for each file
stacked_var_list = load_data(file_path1)
stacked_vbr_list = load_data(file_path2)
stacked_vas_list = load_data(file_path3)
stacked_vbs_list = load_data(file_path4)

import numpy as np

def check_for_nans(data_list, list_name):
    """Function to check for NaN values in a list of datasets."""
    for i, dataset in enumerate(data_list):
        if np.isnan(dataset).any():
            print(f"NaN found in dataset {i} of {list_name}")

# Check each list for NaN values
check_for_nans(stacked_var_list, 'stacked_var_list')
check_for_nans(stacked_vbr_list, 'stacked_vbr_list')
check_for_nans(stacked_vas_list, 'stacked_vas_list')
check_for_nans(stacked_vbs_list, 'stacked_vbs_list')

all_correlations_real1 = []
all_z_correlations_real = []
all_correlations_real2 = []
all_correlations_real3 = []
all_correlations_real4 = []
all_z_correlations_real_sr = []

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    real_corr_sarb = process_data_and_get_corr_matrix(num_pairsa,vas_data, vbr_data)
    all_correlations_real1.append(real_corr_sarb)

    # Calculate average_cross_pair_correlation
    real_corr_rbsa = process_data_and_get_corr_matrix(num_pairsa,vbr_data, vas_data)
    all_correlations_real3.append(real_corr_rbsa)

    real_corr_sbra = process_data_and_get_corr_matrix(num_pairsa,vbs_data, var_data)
    all_correlations_real2.append(real_corr_sbra)

    # Calculate average_cross_pair_correlation
    real_corr_rasb  = process_data_and_get_corr_matrix(num_pairsa,var_data,vbs_data)
    all_correlations_real4.append(real_corr_rasb)
    
    z_corr_matrix_real = calculate_z_corr_matrix2(real_corr_sarb, real_corr_sbra)
    all_z_correlations_real.append(z_corr_matrix_real)
    
    # print("finish real")

import h5py

# Define file paths for saving
file_path5 = 'face268_z_correlations_real_vi.h5'
# Save all_z_correlations_real
with h5py.File(file_path5, 'w') as h5f:
    # Assuming all_z_correlations_real is a list of NumPy arrays
    for i, matrix in enumerate(all_z_correlations_real):
        h5f.create_dataset(f'z_corr_matrix_{i}', data=matrix)
        
print("finish output real")

#-------------------------------
import numpy as np

def calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize):
    all_correlations = []

    for send_pair_num in range(num_pairs):
        send_stack = v1[send_pair_num]
        pair_correlations = []

        for rece_pair_num in range(num_pairs):
            if send_pair_num == rece_pair_num:
                continue  # Skip the same pair

            rece_stack = v2[rece_pair_num]

            # Concatenate the two conditions for this pair
            pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

            # Compute the correlation matrix
            corr_matrix = np.corrcoef(pair_matrix)

            # Fisher's Z Transformation
            fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

            # Extract the part of the matrix that correlates the two conditions
            corr_matrix_half = fisher_z_matrix[:cdsize, cdsize:]
            pair_correlations.append(corr_matrix_half)

        all_correlations.append(pair_correlations)

    return all_correlations

def average_cross_pair_correlation(num_pairs, v1, v2,cdsize):
    all_correlations = calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize)
    average_correlations = []
    for send_pair_num in range(num_pairs):
        avg_corr = np.mean(all_correlations[send_pair_num], axis=0)
        average_correlations.append(avg_corr)
    return average_correlations

def grandavg_norealpair_correlation(v1_list, v2_list):
    grandavg_correlations = []
    for send_pair_num in range(len(v1_list)):
        avg_corr = (v1_list[send_pair_num] + v2_list[send_pair_num]) / 2
        grandavg_correlations.append(avg_corr)
    return grandavg_correlations



all_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_correlations_rasb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rasb = []  # Store cross_pair_correlation for each brain region

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sarb = calculate_cross_pair_correlation(num_pairsa,vas_data, vbr_data, cdsize=24)
    all_correlations_sarb.append(cross_corr_sarb)

    cross_corr_rbsa = calculate_cross_pair_correlation(num_pairsa,vbr_data, vas_data, cdsize=24)
    all_correlations_rbsa.append(cross_corr_rbsa)


for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sbra = calculate_cross_pair_correlation(num_pairsa,vbs_data, var_data, cdsize=24)
    all_correlations_sbra.append(cross_corr_sbra)


    cross_corr_rasb = calculate_cross_pair_correlation(num_pairsa,var_data, vbs_data, cdsize=24)
    all_correlations_rasb.append(cross_corr_rasb)

# # Define file paths for saving
file_path6 = 'face268_cross_correlations_vi.h5'

# Save the data
with h5py.File(file_path6, 'w') as h5f:
    # Assuming all lists are lists of NumPy arrays
    for i, matrix in enumerate(all_correlations_sarb):
        h5f.create_dataset(f'all_correlations_sarb_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rbsa):
        h5f.create_dataset(f'all_correlations_rbsa_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_sbra):
        h5f.create_dataset(f'all_correlations_sbra_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rasb):
        h5f.create_dataset(f'all_correlations_rasb_{i}', data=matrix)
        
print("finish output cross")

# %%
import os
import numpy as np
import nibabel as nib
from nilearn.maskers import NiftiMasker
from scipy.io import loadmat
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import numpy as np


file_path1 = 'speak_va_268.h5'
file_path2 = 'speak_vb_268.h5'
file_path3 = 'listen_va_268.h5'
file_path4 = 'listen_vb_268.h5'

def load_data1(file_path):
    """
    Function to load data from datasets with names p_values1_i and corrected_p_values1_i 
    (where i ranges from 0 to 399) from a given file path, and store them in separate lists.
    """
    data1_list = []  # List to store data from p_values1_ datasets
    with h5py.File(file_path, 'r') as file:
        for i in range(269):  # Iterate over indices from 0 to 399
            pname = f'subarray_{i}'
            # Check and read p_values1_ dataset
            if pname in file:
                if file[pname].shape:  # Check if dataset is not a scalar
                    data1 = file[pname][:]
                else:
                    data1 = file[pname][()]  # Handle scalar dataset
                data1_list.append(data1)
            else:
                print(f"Dataset '{pname}' not found in the file.")

        return data1_list


# Load data for each file
all_vas_list = load_data1(file_path1)
all_vbs_list = load_data1(file_path2)
all_var_list = load_data1(file_path3)
all_vbr_list = load_data1(file_path4)




def process_and_stack(arr):
    f2, f5 = arr[:, 24:36, :10], arr[:, 36:48, :15]
    return np.concatenate([f2.mean(2),f5.mean(2)], axis=1)


# Initialize the final results list
stacked_vas_list = []
stacked_var_list = []
stacked_vbs_list = []
stacked_vbr_list = []


for brain_area in range(268):
    new_vas=all_vas_list[brain_area] 
    new_vbs=all_vbs_list[brain_area] 
    new_var=all_var_list[brain_area] 
    new_vbr=all_vbr_list[brain_area] 
    
    print("Rearranging and stacking data...")
    stacked_vas, stacked_var, stacked_vbs, stacked_vbr = [process_and_stack(data) for data in [new_vas, new_var, new_vbs, new_vbr]]
    print("Data rearranged and stacked.")
    stacked_vas_list.append(stacked_vas)
    stacked_var_list.append(stacked_var)
    stacked_vbs_list.append(stacked_vbs)
    stacked_vbr_list.append(stacked_vbr)


# In[1]:


import h5py
import numpy as np


# Create an HDF5 file
with h5py.File('con268_speak_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vas_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('con268_speak_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbs_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

with h5py.File('con268_listen_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_var_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('con268_listen_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbr_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
# Out:
# Dataset 'subarray_268' not found in the file.
# Dataset 'subarray_268' not found in the file.
# Dataset 'subarray_268' not found in the file.
# Dataset 'subarray_268' not found in the file.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.

# %%
import os
import numpy as np
import nibabel as nib
from nilearn.maskers import NiftiMasker
from scipy.io import loadmat
import seaborn as sns
import matplotlib.pyplot as plt
import h5py
import numpy as np


file_path1 = 'view_va_268.h5'
file_path2 = 'view_vb_268.h5'
file_path3 = 'imagery_va_268.h5'
file_path4 = 'imagery_vb_268.h5'

def load_data1(file_path):
    """
    Function to load data from datasets with names p_values1_i and corrected_p_values1_i 
    (where i ranges from 0 to 399) from a given file path, and store them in separate lists.
    """
    data1_list = []  # List to store data from p_values1_ datasets
    with h5py.File(file_path, 'r') as file:
        for i in range(268):  # Iterate over indices from 0 to 399
            pname = f'subarray_{i}'
            # Check and read p_values1_ dataset
            if pname in file:
                if file[pname].shape:  # Check if dataset is not a scalar
                    data1 = file[pname][:]
                else:
                    data1 = file[pname][()]  # Handle scalar dataset
                data1_list.append(data1)
            else:
                print(f"Dataset '{pname}' not found in the file.")

        return data1_list


# Load data for each file
all_vas_list = load_data1(file_path1)
all_vbs_list = load_data1(file_path2)
all_var_list = load_data1(file_path3)
all_vbr_list = load_data1(file_path4)




def process_and_stack(arr):
    f2, f5 = arr[:, 24:36, :6], arr[:, 36:48, :6]
    return np.concatenate([f2.mean(2),f5.mean(2)], axis=1)


# Initialize the final results list
stacked_vas_list = []
stacked_var_list = []
stacked_vbs_list = []
stacked_vbr_list = []


for brain_area in range(268):
    new_vas=all_vas_list[brain_area] 
    new_vbs=all_vbs_list[brain_area] 
    new_var=all_var_list[brain_area] 
    new_vbr=all_vbr_list[brain_area] 
    
    print("Rearranging and stacking data...")
    stacked_vas, stacked_var, stacked_vbs, stacked_vbr = [process_and_stack(data) for data in [new_vas, new_var, new_vbs, new_vbr]]
    print("Data rearranged and stacked.")
    stacked_vas_list.append(stacked_vas)
    stacked_var_list.append(stacked_var)
    stacked_vbs_list.append(stacked_vbs)
    stacked_vbr_list.append(stacked_vbr)


# In[1]:


import h5py
import numpy as np


# Create an HDF5 file
with h5py.File('con268_view_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vas_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('con268_view_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbs_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)

with h5py.File('con268_imagery_va.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_var_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
with h5py.File('con268_imagery_vb.h5', 'w') as hf:
    # Save each subarray within the list as a dataset
    for i, subarray in enumerate(stacked_vbr_list):
        hf.create_dataset(f'subarray_{i}', data=subarray)
# Out:
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.
# Rearranging and stacking data...
# Data rearranged and stacked.

# %%
import os
import numpy as np
import nibabel as nib
import seaborn as sns
import matplotlib.pyplot as plt

####-------------------------------------
    
import numpy as np

def process_data_and_get_corr_matrix(num_pairs, v1, v2):
    """
    Process data and return the correlation matrices without leave-one-out iteration.
    """
    corr_matrices = []

    for pair_num in range(num_pairs):
        send_stack = v1[pair_num]
        rece_stack = v2[pair_num]

        # Concatenate the two conditions
        pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

        # Calculate the correlation matrix
        corr_matrix = np.corrcoef(pair_matrix)

        # Fisher's Z Transformation
        fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

        # Extract the part of the matrix that correlates the two conditions
        corr_matrix_half = fisher_z_matrix[:send_stack.shape[0], send_stack.shape[0]:]  
        corr_matrices.append(corr_matrix_half)

    corr_matrices = np.array(corr_matrices)

    return corr_matrices


def calculate_z_corr_matrix2(corr_matrices_12, corr_matrices_34):
    corr_matrices_34 = np.array(corr_matrices_34)
    corr_matrices_12 = np.array(corr_matrices_12)
    corr_matrix_all = np.vstack((corr_matrices_12, corr_matrices_34))
    return corr_matrix_all
###---------------------------------------------------------------
import h5py
# Define the file paths
file_path1 = 'con268_imagery_va.h5'
file_path2 = 'con268_imagery_vb.h5'
file_path3 = 'con268_speak_va.h5'
file_path4 = 'con268_speak_vb.h5'

def load_data(file_path):
    """Function to load data from subarray_0 to subarray_199 from a given file path."""
    with h5py.File(file_path, 'r') as file:
        data_list = []
        for i in range(268):  # Load from subarray_0 to subarray_399
            dataset_name = f'subarray_{i}'
            if dataset_name in file:
                data = file[dataset_name][:]
                data_list.append(data)
            else:
                print(f"Dataset '{dataset_name}' not found in the file.")
        return data_list

# Load data for each file
stacked_var_list = load_data(file_path1)
stacked_vbr_list = load_data(file_path2)
stacked_vas_list = load_data(file_path3)
stacked_vbs_list = load_data(file_path4)

import numpy as np

def check_for_nans(data_list, list_name):
    """Function to check for NaN values in a list of datasets."""
    for i, dataset in enumerate(data_list):
        if np.isnan(dataset).any():
            print(f"NaN found in dataset {i} of {list_name}")

# Check each list for NaN values
check_for_nans(stacked_var_list, 'stacked_var_list')
check_for_nans(stacked_vbr_list, 'stacked_vbr_list')
check_for_nans(stacked_vas_list, 'stacked_vas_list')
check_for_nans(stacked_vbs_list, 'stacked_vbs_list')

all_correlations_real1 = []
all_z_correlations_real = []
all_correlations_real2 = []
all_correlations_real3 = []
all_correlations_real4 = []
all_z_correlations_real_sr = []

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    real_corr_sarb = process_data_and_get_corr_matrix(num_pairsa,vas_data, vbr_data)
    all_correlations_real1.append(real_corr_sarb)

    # Calculate average_cross_pair_correlation
    real_corr_rbsa = process_data_and_get_corr_matrix(num_pairsa,vbr_data, vas_data)
    all_correlations_real3.append(real_corr_rbsa)

    real_corr_sbra = process_data_and_get_corr_matrix(num_pairsa,vbs_data, var_data)
    all_correlations_real2.append(real_corr_sbra)

    # Calculate average_cross_pair_correlation
    real_corr_rasb  = process_data_and_get_corr_matrix(num_pairsa,var_data,vbs_data)
    all_correlations_real4.append(real_corr_rasb)
    
    z_corr_matrix_real = calculate_z_corr_matrix2(real_corr_sarb, real_corr_sbra)
    all_z_correlations_real.append(z_corr_matrix_real)
    
    # print("finish real")

import h5py

# Define file paths for saving
file_path5 = 'con268_z_correlations_real_si.h5'
# Save all_z_correlations_real
with h5py.File(file_path5, 'w') as h5f:
    # Assuming all_z_correlations_real is a list of NumPy arrays
    for i, matrix in enumerate(all_z_correlations_real):
        h5f.create_dataset(f'z_corr_matrix_{i}', data=matrix)
        
print("finish output real")

#-------------------------------
import numpy as np

def calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize):
    all_correlations = []

    for send_pair_num in range(num_pairs):
        send_stack = v1[send_pair_num]
        pair_correlations = []

        for rece_pair_num in range(num_pairs):
            if send_pair_num == rece_pair_num:
                continue  # Skip the same pair

            rece_stack = v2[rece_pair_num]

            # Concatenate the two conditions for this pair
            pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

            # Compute the correlation matrix
            corr_matrix = np.corrcoef(pair_matrix)

            # Fisher's Z Transformation
            fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

            # Extract the part of the matrix that correlates the two conditions
            corr_matrix_half = fisher_z_matrix[:cdsize, cdsize:]
            pair_correlations.append(corr_matrix_half)

        all_correlations.append(pair_correlations)

    return all_correlations

def average_cross_pair_correlation(num_pairs, v1, v2,cdsize):
    all_correlations = calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize)
    average_correlations = []
    for send_pair_num in range(num_pairs):
        avg_corr = np.mean(all_correlations[send_pair_num], axis=0)
        average_correlations.append(avg_corr)
    return average_correlations

def grandavg_norealpair_correlation(v1_list, v2_list):
    grandavg_correlations = []
    for send_pair_num in range(len(v1_list)):
        avg_corr = (v1_list[send_pair_num] + v2_list[send_pair_num]) / 2
        grandavg_correlations.append(avg_corr)
    return grandavg_correlations



all_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_correlations_rasb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rasb = []  # Store cross_pair_correlation for each brain region

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sarb = calculate_cross_pair_correlation(num_pairsa,vas_data, vbr_data, cdsize=24)
    all_correlations_sarb.append(cross_corr_sarb)

    cross_corr_rbsa = calculate_cross_pair_correlation(num_pairsa,vbr_data, vas_data, cdsize=24)
    all_correlations_rbsa.append(cross_corr_rbsa)


for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sbra = calculate_cross_pair_correlation(num_pairsa,vbs_data, var_data, cdsize=24)
    all_correlations_sbra.append(cross_corr_sbra)


    cross_corr_rasb = calculate_cross_pair_correlation(num_pairsa,var_data, vbs_data, cdsize=24)
    all_correlations_rasb.append(cross_corr_rasb)

# # Define file paths for saving
file_path6 = 'con268_cross_correlations_si.h5'

# Save the data
with h5py.File(file_path6, 'w') as h5f:
    # Assuming all lists are lists of NumPy arrays
    for i, matrix in enumerate(all_correlations_sarb):
        h5f.create_dataset(f'all_correlations_sarb_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rbsa):
        h5f.create_dataset(f'all_correlations_rbsa_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_sbra):
        h5f.create_dataset(f'all_correlations_sbra_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rasb):
        h5f.create_dataset(f'all_correlations_rasb_{i}', data=matrix)
        
print("finish output cross")
# Out:
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2208066704.py:28: RuntimeWarning: divide by zero encountered in divide
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2208066704.py:28: RuntimeWarning: divide by zero encountered in log
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# C:\Users\yshen\anaconda3\envs\shen\Lib\site-packages\numpy\lib\_function_base_impl.py:3065: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# C:\Users\yshen\anaconda3\envs\shen\Lib\site-packages\numpy\lib\_function_base_impl.py:3066: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# finish output real
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2208066704.py:156: RuntimeWarning: divide by zero encountered in divide
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2208066704.py:156: RuntimeWarning: divide by zero encountered in log
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# finish output cross

# %%
import os
import numpy as np
import nibabel as nib
import seaborn as sns
import matplotlib.pyplot as plt

####-------------------------------------
    
import numpy as np

def process_data_and_get_corr_matrix(num_pairs, v1, v2):
    """
    Process data and return the correlation matrices without leave-one-out iteration.
    """
    corr_matrices = []

    for pair_num in range(num_pairs):
        send_stack = v1[pair_num]
        rece_stack = v2[pair_num]

        # Concatenate the two conditions
        pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

        # Calculate the correlation matrix
        corr_matrix = np.corrcoef(pair_matrix)

        # Fisher's Z Transformation
        fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

        # Extract the part of the matrix that correlates the two conditions
        corr_matrix_half = fisher_z_matrix[:send_stack.shape[0], send_stack.shape[0]:]  
        corr_matrices.append(corr_matrix_half)

    corr_matrices = np.array(corr_matrices)

    return corr_matrices


def calculate_z_corr_matrix2(corr_matrices_12, corr_matrices_34):
    corr_matrices_34 = np.array(corr_matrices_34)
    corr_matrices_12 = np.array(corr_matrices_12)
    corr_matrix_all = np.vstack((corr_matrices_12, corr_matrices_34))
    return corr_matrix_all
###---------------------------------------------------------------
import h5py
# Define the file paths
file_path1 = 'con268_imagery_va.h5'
file_path2 = 'con268_imagery_vb.h5'
file_path3 = 'con268_view_va.h5'
file_path4 = 'con268_view_vb.h5'

def load_data(file_path):
    """Function to load data from subarray_0 to subarray_199 from a given file path."""
    with h5py.File(file_path, 'r') as file:
        data_list = []
        for i in range(268):  # Load from subarray_0 to subarray_399
            dataset_name = f'subarray_{i}'
            if dataset_name in file:
                data = file[dataset_name][:]
                data_list.append(data)
            else:
                print(f"Dataset '{dataset_name}' not found in the file.")
        return data_list

# Load data for each file
stacked_var_list = load_data(file_path1)
stacked_vbr_list = load_data(file_path2)
stacked_vas_list = load_data(file_path3)
stacked_vbs_list = load_data(file_path4)

import numpy as np

def check_for_nans(data_list, list_name):
    """Function to check for NaN values in a list of datasets."""
    for i, dataset in enumerate(data_list):
        if np.isnan(dataset).any():
            print(f"NaN found in dataset {i} of {list_name}")

# Check each list for NaN values
check_for_nans(stacked_var_list, 'stacked_var_list')
check_for_nans(stacked_vbr_list, 'stacked_vbr_list')
check_for_nans(stacked_vas_list, 'stacked_vas_list')
check_for_nans(stacked_vbs_list, 'stacked_vbs_list')

all_correlations_real1 = []
all_z_correlations_real = []
all_correlations_real2 = []
all_correlations_real3 = []
all_correlations_real4 = []
all_z_correlations_real_sr = []

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    real_corr_sarb = process_data_and_get_corr_matrix(num_pairsa,vas_data, vbr_data)
    all_correlations_real1.append(real_corr_sarb)

    # Calculate average_cross_pair_correlation
    real_corr_rbsa = process_data_and_get_corr_matrix(num_pairsa,vbr_data, vas_data)
    all_correlations_real3.append(real_corr_rbsa)

    real_corr_sbra = process_data_and_get_corr_matrix(num_pairsa,vbs_data, var_data)
    all_correlations_real2.append(real_corr_sbra)

    # Calculate average_cross_pair_correlation
    real_corr_rasb  = process_data_and_get_corr_matrix(num_pairsa,var_data,vbs_data)
    all_correlations_real4.append(real_corr_rasb)
    
    z_corr_matrix_real = calculate_z_corr_matrix2(real_corr_sarb, real_corr_sbra)
    all_z_correlations_real.append(z_corr_matrix_real)
    
    # print("finish real")

import h5py

# Define file paths for saving
file_path5 = 'con268_z_correlations_real_vi.h5'
# Save all_z_correlations_real
with h5py.File(file_path5, 'w') as h5f:
    # Assuming all_z_correlations_real is a list of NumPy arrays
    for i, matrix in enumerate(all_z_correlations_real):
        h5f.create_dataset(f'z_corr_matrix_{i}', data=matrix)
        
print("finish output real")

#-------------------------------
import numpy as np

def calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize):
    all_correlations = []

    for send_pair_num in range(num_pairs):
        send_stack = v1[send_pair_num]
        pair_correlations = []

        for rece_pair_num in range(num_pairs):
            if send_pair_num == rece_pair_num:
                continue  # Skip the same pair

            rece_stack = v2[rece_pair_num]

            # Concatenate the two conditions for this pair
            pair_matrix = np.concatenate((send_stack, rece_stack), axis=0)

            # Compute the correlation matrix
            corr_matrix = np.corrcoef(pair_matrix)

            # Fisher's Z Transformation
            fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))

            # Extract the part of the matrix that correlates the two conditions
            corr_matrix_half = fisher_z_matrix[:cdsize, cdsize:]
            pair_correlations.append(corr_matrix_half)

        all_correlations.append(pair_correlations)

    return all_correlations

def average_cross_pair_correlation(num_pairs, v1, v2,cdsize):
    all_correlations = calculate_cross_pair_correlation(num_pairs, v1, v2, cdsize)
    average_correlations = []
    for send_pair_num in range(num_pairs):
        avg_corr = np.mean(all_correlations[send_pair_num], axis=0)
        average_correlations.append(avg_corr)
    return average_correlations

def grandavg_norealpair_correlation(v1_list, v2_list):
    grandavg_correlations = []
    for send_pair_num in range(len(v1_list)):
        avg_corr = (v1_list[send_pair_num] + v2_list[send_pair_num]) / 2
        grandavg_correlations.append(avg_corr)
    return grandavg_correlations



all_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_correlations_rasb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sarb = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rbsa = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_sbra = []  # Store cross_pair_correlation for each brain region
all_avg_correlations_rasb = []  # Store cross_pair_correlation for each brain region

num_pairsa=23

for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vas_data = stacked_vas_list[brain_area]  # shape (23, 24, number_of_voxels)
    vbr_data = stacked_vbr_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sarb = calculate_cross_pair_correlation(num_pairsa,vas_data, vbr_data, cdsize=24)
    all_correlations_sarb.append(cross_corr_sarb)

    cross_corr_rbsa = calculate_cross_pair_correlation(num_pairsa,vbr_data, vas_data, cdsize=24)
    all_correlations_rbsa.append(cross_corr_rbsa)


for brain_area in range(268):
    # Extract the corresponding data for each brain region
    vbs_data = stacked_vbs_list[brain_area]  # shape (23, 24, number_of_voxels)
    var_data = stacked_var_list[brain_area]  # shape (23, 24, number_of_voxels)

    # Calculate cross_pair_correlation
    cross_corr_sbra = calculate_cross_pair_correlation(num_pairsa,vbs_data, var_data, cdsize=24)
    all_correlations_sbra.append(cross_corr_sbra)


    cross_corr_rasb = calculate_cross_pair_correlation(num_pairsa,var_data, vbs_data, cdsize=24)
    all_correlations_rasb.append(cross_corr_rasb)

# # Define file paths for saving
file_path6 = 'con268_cross_correlations_vi.h5'

# Save the data
with h5py.File(file_path6, 'w') as h5f:
    # Assuming all lists are lists of NumPy arrays
    for i, matrix in enumerate(all_correlations_sarb):
        h5f.create_dataset(f'all_correlations_sarb_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rbsa):
        h5f.create_dataset(f'all_correlations_rbsa_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_sbra):
        h5f.create_dataset(f'all_correlations_sbra_{i}', data=matrix)

    for i, matrix in enumerate(all_correlations_rasb):
        h5f.create_dataset(f'all_correlations_rasb_{i}', data=matrix)
        
print("finish output cross")
# Out:
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2506845383.py:28: RuntimeWarning: divide by zero encountered in divide
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2506845383.py:28: RuntimeWarning: divide by zero encountered in log
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# finish output real
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2506845383.py:156: RuntimeWarning: divide by zero encountered in divide
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# C:\Users\yshen\AppData\Local\Temp\2\ipykernel_17732\2506845383.py:156: RuntimeWarning: divide by zero encountered in log
#   fisher_z_matrix = 0.5 * np.log((1 + corr_matrix) / (1 - corr_matrix))
# finish output cross
